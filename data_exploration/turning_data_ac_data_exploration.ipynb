# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# Read the CSV file located in the current directory
# The file name is 'turning_data_for_ai_simulations.csv'  
# df = pd.read_csv('c:/dev/hackaping_2025/input/labeled_data.csv')



df = pd.read_csv('c:/dev/hackaping_2025/input/turning_data_for_ai_simulations.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#    Item Id  Material Length (mm)  Operation Time Per PC  \
# 0        1                    13                  3.480
# 1        2                    24                  4.610
# 2        3                    13                  3.030
# 3        4                    53                  5.091
# 4        5                    26                  4.810
#
#   Unit for Operation Time  Machine Id  FORECAST_YEAR  \
# 0                     MIN    55235206           6941
# 1                     MIN    55235207           5007
# 2                     MIN    55235206           4982
# 3                     MIN    55235206           4308
# 4                     MIN    55235207           4064
#
#    Current FIXED_LOT_SIZE (This should be optimized)  Consumed January  \
# 0                                                493               603
# 1                                                528               562
# 2                                                419               307
# 3                                                440               585
# 4                                                581               320
#
#    Consumed February  Consumed March  Consumed April  Consumed May  \
# 0                430             598             585           612
# 1                494             466             719           525
# 2                270             412             441           540
# 3                568             570             571           572
# 4                360             240             381           241
#
#    Consumed June  Consumed July  Consumed August  Consumed September  \
# 0            497            166              277                 415
# 1            542             51              372                 345
# 2            323            201              295                 486
# 3              0            591                0                 577
# 4            193            200              241                 292
#
#    Consumed October  Consumed November  Consumed December  \
# 0               610                300                169
# 1               614                438                319
# 2               558                107                337
# 3                 0                561                573
# 4               321                280                280
#
#    Consumed Total 2024:  Actual vs. FC
# 0                  5262          -1679
# 1                  5447            440
# 2                  4277           -705
# 3                  5168            860
# 4                  3349           -715

# %%
# Check for null or missing values in the DataFrame
df.isnull().sum()
# Out:
# Item Id                                              0
# Material Length (mm)                                 0
# Operation Time Per PC                                0
# Unit for Operation Time                              0
# Machine Id                                           0
# FORECAST_YEAR                                        0
# Current FIXED_LOT_SIZE (This should be optimized)    0
# Consumed January                                     0
# Consumed February                                    0
# Consumed March                                       0
# Consumed April                                       0
# Consumed May                                         0
# Consumed June                                        0
# Consumed July                                        0
# Consumed August                                      0
# Consumed September                                   0
# Consumed October                                     0
# Consumed November                                    0
# Consumed December                                    0
# Consumed Total 2024:                                 0
# Actual vs. FC                                        0
# dtype: int64

# %%
# Genereate a summary of the DataFrame
df.describe(include='all')
# Out:
#            Item Id  Material Length (mm)  Operation Time Per PC  \
# count   491.000000            491.000000             491.000000
# unique         NaN                   NaN                    NaN
# top            NaN                   NaN                    NaN
# freq           NaN                   NaN                    NaN
# mean    246.024440             57.319756               9.654255
# std     141.925172             33.199361               5.409490
# min       1.000000             13.000000               2.550000
# 25%     123.500000             34.000000               6.110000
# 50%     246.000000             50.000000               8.210000
# 75%     368.500000             70.500000              11.330000
# max     492.000000            260.000000              51.760000
#
#        Unit for Operation Time    Machine Id  FORECAST_YEAR  \
# count                      491  4.910000e+02     491.000000
# unique                       1           NaN            NaN
# top                        MIN           NaN            NaN
# freq                       491           NaN            NaN
# mean                       NaN  5.523522e+07     373.372709
# std                        NaN  1.607598e+01     750.315733
# min                        NaN  5.523521e+07       0.000000
# 25%                        NaN  5.523521e+07       0.000000
# 50%                        NaN  5.523521e+07      65.000000
# 75%                        NaN  5.523524e+07     385.500000
# max                        NaN  5.523524e+07    6941.000000
#
#         Current FIXED_LOT_SIZE (This should be optimized)  Consumed January  \
# count                                          491.000000        491.000000
# unique                                                NaN               NaN
# top                                                   NaN               NaN
# freq                                                  NaN               NaN
# mean                                            80.105906         36.887984
# std                                             92.249932         93.292002
# min                                             10.000000          0.000000
# 25%                                             10.000000          0.000000
# 50%                                             43.000000          0.000000
# 75%                                            110.500000         12.000000
# max                                            581.000000        603.000000
#
#         Consumed February  Consumed March  Consumed April  Consumed May  \
# count          491.000000      491.000000      491.000000    491.000000
# unique                NaN             NaN             NaN           NaN
# top                   NaN             NaN             NaN           NaN
# freq                  NaN             NaN             NaN           NaN
# mean            33.026477       28.236253       33.232179     31.533605
# std             91.888871       77.803895       89.021593     86.360542
# min              0.000000        0.000000        0.000000      0.000000
# 25%              0.000000        0.000000        0.000000      0.000000
# 50%              0.000000        0.000000        0.000000      0.000000
# 75%              8.500000        6.500000        6.000000      6.500000
# max            586.000000      598.000000      719.000000    612.000000
#
#         Consumed June  Consumed July  Consumed August  Consumed September  \
# count      491.000000     491.000000       491.000000          491.000000
# unique            NaN            NaN              NaN                 NaN
# top               NaN            NaN              NaN                 NaN
# freq              NaN            NaN              NaN                 NaN
# mean        24.065173      17.002037        19.207739           29.492872
# std         71.251723      62.270853        55.725948           82.549363
# min          0.000000       0.000000         0.000000            0.000000
# 25%          0.000000       0.000000         0.000000            0.000000
# 50%          0.000000       0.000000         0.000000            0.000000
# 75%          2.000000       0.000000         2.000000           10.500000
# max        542.000000     591.000000       380.000000          810.000000
#
#         Consumed October  Consumed November  Consumed December  \
# count         491.000000         491.000000         491.000000
# unique               NaN                NaN                NaN
# top                  NaN                NaN                NaN
# freq                 NaN                NaN                NaN
# mean           35.380855          28.193483          18.150713
# std           102.682866          73.888120          59.685483
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%            11.500000           7.000000           1.000000
# max           990.000000         561.000000         573.000000
#
#         Consumed Total 2024:  Actual vs. FC
# count             491.000000      491.00000
# unique                   NaN            NaN
# top                      NaN            NaN
# freq                     NaN            NaN
# mean              334.409369      -38.96334
# std               714.897676      265.32775
# min                 0.000000    -1679.00000
# 25%                 0.000000      -44.50000
# 50%                61.000000        0.00000
# 75%               334.000000       13.00000
# max              5447.000000     1220.00000

# %%
# Create histograms for all numeric columns in the DataFrame
df.hist(figsize=(20, 15), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<Axes: title={'center': 'Item Id'}>,
#         <Axes: title={'center': 'Material Length (mm)'}>,
#         <Axes: title={'center': 'Operation Time Per PC'}>,
#         <Axes: title={'center': 'Machine Id'}>],
#        [<Axes: title={'center': 'FORECAST_YEAR'}>,
#         <Axes: title={'center': 'Current FIXED_LOT_SIZE (This should be optimized)'}>,
#         <Axes: title={'center': 'Consumed January'}>,
#         <Axes: title={'center': 'Consumed February'}>],
#        [<Axes: title={'center': 'Consumed March'}>,
#         <Axes: title={'center': 'Consumed April'}>,
#         <Axes: title={'center': 'Consumed May'}>,
#         <Axes: title={'center': 'Consumed June'}>],
#        [<Axes: title={'center': 'Consumed July'}>,
#         <Axes: title={'center': 'Consumed August'}>,
#         <Axes: title={'center': 'Consumed September'}>,
#         <Axes: title={'center': 'Consumed October'}>],
#        [<Axes: title={'center': 'Consumed November'}>,
#         <Axes: title={'center': 'Consumed December'}>,
#         <Axes: title={'center': 'Consumed Total 2024:'}>,
#         <Axes: title={'center': 'Actual vs. FC'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt

# Show scatter plot using Operation Time Per PC for X and and the Item ID for Y
plt.scatter(df['Operation Time Per PC'], df['Item Id'])
plt.xlabel('Operation Time Per PC')
plt.ylabel('Item ID')
plt.title('Scatter plot of Operation Time Per PC vs Item Id')
plt.show()

# List the outliers of the Operation Time Per PC column showing Item ID, Operation Time Per PC, Machine ID and Material Length
threshold = df['Operation Time Per PC'].quantile(0.90)
outliers = df[df['Operation Time Per PC'] > threshold]

# Sort the outliers by Operation Time Per PC in descending order
outliers = outliers.sort_values(by='Operation Time Per PC', ascending=False)
outliers[['Item Id', 'Operation Time Per PC', 'Machine Id', 'Material Length (mm)']].head(10)
# Out:
#      Item Id  Operation Time Per PC  Machine Id  Material Length (mm)
# 473      474                  51.76    55235241                   243
# 58        59                  34.51    55235240                   112
# 202      203                  33.15    55235241                   260
# 388      389                  29.46    55235206                    39
# 181      182                  26.97    55235241                    48
# 61        62                  26.95    55235241                    78
# 40        41                  26.74    55235240                    79
# 140      141                  25.93    55235241                    48
# 207      208                  25.68    55235206                    36
# 122      123                  25.00    55235207                    97
