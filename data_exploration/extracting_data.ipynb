# %%
import pandas as pd

# %%
df = pd.read_csv('turning_data_for_ai_simulations_items.csv')
df = df.dropna()
df.head()
# Out:
#    Item Id  Material Length (mm)  Operation Time Per PC  \
# 0        1                    13                  3.480
# 1        2                    24                  4.610
# 2        3                    13                  3.030
# 3        4                    53                  5.091
# 4        5                    26                  4.810
#
#   Unit for Operation Time  Machine Id  FORECAST_YEAR  \
# 0                     MIN    55235206           6941
# 1                     MIN    55235207           5007
# 2                     MIN    55235206           4982
# 3                     MIN    55235206           4308
# 4                     MIN    55235207           4064
#
#    Current FIXED_LOT_SIZE (This should be optimized)  Consumed January  \
# 0                                                493               603
# 1                                                528               562
# 2                                                419               307
# ...

# %%
df.keys()
# Out:
# Index(['Item Id', 'Material Length (mm)', 'Operation Time Per PC',
#        'Unit for Operation Time', 'Machine Id', 'FORECAST_YEAR',
#        'Current FIXED_LOT_SIZE (This should be optimized)', 'Consumed January',
#        'Consumed February', 'Consumed March', 'Consumed April', 'Consumed May',
#        'Consumed June', 'Consumed July', 'Consumed August',
#        'Consumed September', 'Consumed October', 'Consumed November',
#        'Consumed December', 'Consumed Total 2024:', 'Actual vs. FC'],
#       dtype='object')

# %% [markdown]
# ## variable selection

# %%
data = pd.DataFrame()
data["process_time"] = df["Operation Time Per PC"]
data["demand"] = df["Consumed January"]

# %%
data.head()
# Out:
#    process_time  demand
# 0         3.480     603
# 1         4.610     562
# 2         3.030     307
# 3         5.091     585
# 4         4.810     320
